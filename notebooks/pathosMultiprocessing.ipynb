# %%
import collections
import pandas as pd
import time
from pathos.multiprocessing import ProcessingPool as Pool

# %%
data = pd.read_csv('https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv')
data.reset_index(inplace=True) #Use idx as identifier
data.head()
# Out:
#    index  sepal_length  sepal_width  petal_length  petal_width species
# 0      0           5.1          3.5           1.4          0.2  setosa
# 1      1           4.9          3.0           1.4          0.2  setosa
# 2      2           4.7          3.2           1.3          0.2  setosa
# 3      3           4.6          3.1           1.5          0.2  setosa
# 4      4           5.0          3.6           1.4          0.2  setosa

# %%
### Convert df to named tuple
irises = tuple(data.itertuples(name='Iris', index=False))

# %%
### Multiprocessing implementation
pool = Pool()
# Out:
# processing: 0processing: 15processing: 5processing: 10processing: 20processing: 25processing: 30
#
#
#
#
# processing: 35
#
#
# done with: 0done with: 10done with: 15done with: 5done with: 20done with: 25
# done with: 35
# done with: 30
#
#
#
# processing: 1processing: 11
#
# processing: 16processing: 21processing: 6processing: 36processing: 26
#
# processing: 31
#
#
#
#
#
# done with: 11done with: 1
# done with: 36done with: 16done with: 21done with: 6done with: 26done with: 31
#
#
#
# processing: 12
#
# processing: 2
#
# processing: 17processing: 7processing: 22processing: 27processing: 37
# processing: 32
#
#
#
#
#
# done with: 12done with: 2done with: 17done with: 7done with: 22
# done with: 27done with: 32done with: 37
#
# processing: 13
#
#
#
#
# processing: 3processing: 18
# processing: 33processing: 28processing: 23processing: 8processing: 38
#
#
#
#
#
#
# done with: 13done with: 18done with: 3
# done with: 33done with: 28done with: 8done with: 23done with: 38
#
# processing: 14
#
#
#
#
# processing: 4
# processing: 19processing: 34processing: 9processing: 29processing: 39processing: 24
#
#
#
#
#
#
# done with: 14
# done with: 4done with: 19done with: 34done with: 29done with: 24done with: 9done with: 39
#
#
#
#
# processing: 40
#
#
# processing: 45processing: 50processing: 55processing: 60processing: 65processing: 70
#
#
#
#
#
# processing: 75
# done with: 40done with: 45done with: 55done with: 50
# done with: 65done with: 60done with: 70
# processing: 41
#
#
#
#
# done with: 75
# processing: 56processing: 46processing: 61processing: 66processing: 51processing: 71
#
#
#
#
# processing: 76
#
#
# done with: 41done with: 66
# done with: 51done with: 46done with: 71done with: 61done with: 56done with: 76
# processing: 42
#
#
#
#
#
# processing: 47
# processing: 67processing: 52processing: 72processing: 62processing: 57
#
# processing: 77
#
#
#
#
# done with: 42
# processing: 43done with: 67done with: 47
# done with: 72done with: 52done with: 62done with: 57
#
# done with: 77processing: 68
#
#
#
# processing: 48
# processing: 73processing: 63processing: 53processing: 58
#
# processing: 78
#
#
#
#
# done with: 43
# processing: 44
# done with: 68
# done with: 48done with: 63done with: 73done with: 53done with: 58
# done with: 78processing: 69
#
#
#
#
# processing: 49
# processing: 74processing: 59processing: 64processing: 54
# processing: 79
#
#
#
#
# done with: 44
# processing: 80done with: 69
# done with: 49done with: 59done with: 74processing: 85
#
# done with: 64done with: 54done with: 79
# processing: 90processing: 95
# processing: 100
#
#
#
#
# processing: 105processing: 110processing: 115
#
#
# done with: 85
# done with: 100done with: 90done with: 95processing: 86
#
# done with: 105
# processing: 91
# processing: 101
# done with: 110done with: 115processing: 96
# processing: 106
#
#
#
#
# processing: 111processing: 116
#
#
# done with: 86
# done with: 101done with: 91done with: 96done with: 106
# processing: 87
#
# done with: 111done with: 116
# processing: 92processing: 107
#
# processing: 102processing: 97
# processing: 112
#
#
#
# processing: 117
#
# done with: 80
# processing: 81
# done with: 87done with: 107done with: 97done with: 112done with: 92
# done with: 102
#
#
# processing: 88
# done with: 117
# processing: 108processing: 113processing: 93processing: 98
#
#
# processing: 103
#
# processing: 118
#
#
# done with: 81
# processing: 82
# done with: 108done with: 88done with: 113done with: 93done with: 98done with: 118done with: 103
#
#
#
#
#
#
# processing: 89processing: 109processing: 94processing: 119processing: 114processing: 99processing: 104
#
#
#
#
#
#
# done with: 82
# processing: 83
# done with: 94done with: 89done with: 109done with: 114done with: 119done with: 99done with: 104
#
#
#
#
#
#
# processing: 125processing: 120processing: 130processing: 135processing: 140processing: 145
#
#
#
#
#
# done with: 83
# processing: 84
# done with: 120done with: 125done with: 140done with: 130done with: 135done with: 145
#
#
#
#
# processing: 121
# processing: 141processing: 131processing: 126processing: 136processing: 146
#
#
#
#
# done with: 84
#
# done with: 131done with: 141done with: 121done with: 126done with: 136done with: 146
#
#
#
#
#
# processing: 142processing: 137processing: 132processing: 122processing: 127
#
#
#
# processing: 147
#
# done with: 132done with: 142done with: 127done with: 137done with: 122done with: 147
#
#
#
#
# processing: 143
# processing: 133processing: 128processing: 123processing: 138
#
#
#
#
#
# processing: 148done with: 123done with: 138done with: 143done with: 133done with: 128done with: 148
#
#
#
#
#
# processing: 129processing: 139processing: 124processing: 144processing: 134processing: 149

# %%
def getAreaSlowTuples(x,verbose=True):
    x = tuple(x)
    if verbose: print(f'processing: {x[0]}')
    time.sleep(.05)
    result = {'ID':x[0],
            'sepArea':x[1] * x[2],
            'petArea':x[3] * x[4]}
    if verbose: print(f'done with: {x[0]}')
    return result

# %%
tIris = [tuple(_) for _ in irises]

# %%
# %time 
## Map function over
start = time.time()
resParallel = pool.map(getAreaSlowTuples, tIris)
end = time.time()
print(f'time: {end-start:.4f}s\n')
# Out:
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 7.87 µs
